# %% [markdown]
# ### Langchain
#
# 1. Get setup with langchain , langsmith, and langserver
# 2. Use the most basic and common components of the langchain: prompt templates, models and output parser
# 3. Build a simple applications with langchain
# 4. Trace your application with langsmith
# 5. Serve your application with langServe
