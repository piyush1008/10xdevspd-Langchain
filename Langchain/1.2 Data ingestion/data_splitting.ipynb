# %%
from langchain_community.document_loaders import PyPDFLoader

loader=PyPDFLoader("DSA_1672567308.pdf")

docs=loader.load()  
docs
# Out:
# /Users/piyushdubey/Documents/AI/langchain/venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# [Document(metadata={'producer': 'iOS Version 17.4.1 (Build 21E236) Quartz PDFContext, AppendMode 1.1', 'creator': 'PyPDF', 'creationdate': '', 'moddate': "D:20240522044705Z00'00'", 'source': 'DSA_1672567308.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}, page_content='@Aakash Kanojiya'),
#  Document(metadata={'producer': 'iOS Version 17.4.1 (Build 21E236) Quartz PDFContext, AppendMode 1.1', 'creator': 'PyPDF', 'creationdate': '', 'moddate': "D:20240522044705Z00'00'", 'source': 'DSA_1672567308.pdf', 'total_pages': 9, 'page': 1, 'page_label': '2'}, page_content='@Aakash Kanojiya'),
# ...

# %% [markdown]
# ### how to use recursively split text by character

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)

final_documents=text_splitter.#(docs)
final_documents

print(final_documents[0])
print(final_documents[1])
# Out:
# page_content='@Aakash Kanojiya' metadata={'producer': 'iOS Version 17.4.1 (Build 21E236) Quartz PDFContext, AppendMode 1.1', 'creator': 'PyPDF', 'creationdate': '', 'moddate': "D:20240522044705Z00'00'", 'source': 'DSA_1672567308.pdf', 'total_pages': 9, 'page': 0, 'page_label': '1'}
# page_content='@Aakash Kanojiya' metadata={'producer': 'iOS Version 17.4.1 (Build 21E236) Quartz PDFContext, AppendMode 1.1', 'creator': 'PyPDF', 'creationdate': '', 'moddate': "D:20240522044705Z00'00'", 'source': 'DSA_1672567308.pdf', 'total_pages': 9, 'page': 1, 'page_label': '2'}

# %%
from langchain_community.document_loaders import TextLoader

loader=TextLoader("speech.txt").load()
loader

# l=loader[0].page_content.split("\n")
# print(l)
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Hii there\nthis is the welcome class on data ingestion\nYou should be good now')]

# %%
from langchain_community.document_loaders.base_o365 import CHUNK_SIZE
from requests.models import ChunkedEncodingError


speech=""
with open("speech.txt","r") as file:
    speech=file.read()
speech

text_splitter=RecursiveCharacterTextSplitter(chunk_size=10, chunk_overlap=2)
final_docs=text_splitter.create_documents([speech])
final_docs
# Out:
# [Document(metadata={}, page_content='Hii there'),
#  Document(metadata={}, page_content='this is'),
#  Document(metadata={}, page_content='the'),
#  Document(metadata={}, page_content='welcome'),
#  Document(metadata={}, page_content='class on'),
#  Document(metadata={}, page_content='data'),
#  Document(metadata={}, page_content='ingestion'),
#  Document(metadata={}, page_content='You'),
#  Document(metadata={}, page_content='should be'),
#  Document(metadata={}, page_content='good now')]
